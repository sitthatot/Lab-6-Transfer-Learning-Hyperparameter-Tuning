# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader,Subset,Dataset

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
import os
import cv2
from skimage.util import random_noise
from sklearn.model_selection import train_test_split
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

seed = 4912
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
### START CODE HERE ###
class CustomImageDataset(Dataset):
    def __init__(self, image_paths,gauss_noise=False,gauss_blur=None,resize=128,p=0.5, center_crop=False, transform=None):
        self.p = p
        self.resize = resize
        self.gauss_noise = gauss_noise
        self.gauss_blur = gauss_blur
        self.center_crop = center_crop
        self.image_paths = image_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def add_gaussian_noise(self, image):
        #สร้าง gaussian noise
        x, y, channel = image.shape
        mean = random.uniform(-50, 50)
        gaussian_noise = np.random.normal(loc=mean,scale=100,size=(x,y,channel)).astype(np.float32)
        #ภาพ ผสมกับ Gaussian Noise
        noisy_image = image + gaussian_noise
        return np.clip(noisy_image, 0, 255).astype(np.uint8)

    def do_gaussian_blur(self, image):
        kernel_size = random.randrange(3, 12, 2)
        return cv2.GaussianBlur(image, (kernel_size, kernel_size), 0) #ภาพ,Kernel Size, Standard Deviation
    
    def do_center_crop(self, image, desire_h=128, desire_w=128):
        height,width, _ = image.shape
        if width <= height: #กรณี width สั้น ให้ resize โดยยึด width 
            #ปรับ width เทียบเท่าแล้ว เหลือ Height ที่ยังเกิน
            #เพื่อให้สัดส่วนคงเดิม ไม่ถูกบีบ ให้หาอัตราส่วนภาพ
            img_ratio = height / width
            image = cv2.resize(image, (self.resize, int(self.resize*img_ratio))) #image , (width, height) ที่จะไป
            #พอ resize แล้ว จะได้ width height ตัวใหม่ 
            new_resize_h, new_resize_w, _ = image.shape
            crop_img = image[new_resize_h//2 - self.resize//2: new_resize_h//2 + self.resize//2, 0:self.resize]
        else:
            #ปรับ Height เทียบเท่าแล้ว เหลือ width ที่ยังเกิน
            img_ratio = width / height
            image = cv2.resize(image, (int(self.resize*img_ratio), self.resize))
            new_resize_h, new_resize_w, _ = image.shape
            crop_img = image[0:self.resize, new_resize_w//2 - self.resize//2: new_resize_w//2 + self.resize//2]
        return crop_img

    def __getitem__(self, idx):
        image_paths = self.image_paths[idx]
        if not os.path.exists(image_paths):
            print(f"File {image_paths} not found, skipping.")
            return None  # Handle this case in the training loop
        img = plt.imread(image_paths)
        if img.ndim == 2: #ถ้าเป็น Gray --> บังคับเป็น RGB Format
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        
        #ถ้าทำ center crop ก็ไม่ต้องทำ Resize, เลือกอย่างใดอย่างนึง
        if(self.center_crop):
            gt_image = self.do_center_crop(img, desire_h=self.resize, desire_w=self.resize)
            # print("*******")
            # print(gt_image.shape)
        else:
            gt_image = cv2.resize(img, (self.resize, self.resize))  #Ground truth image
        image = gt_image.copy()

    # Ensure minimum size of 7x7
        if image.shape[0] < 7 or image.shape[1] < 7:
            image = cv2.resize(image, (max(7, image.shape[1]), max(7, image.shape[0])))
        if gt_image.shape[0] < 7 or gt_image.shape[1] < 7:
            gt_image = cv2.resize(gt_image, (max(7, gt_image.shape[1]), max(7, gt_image.shape[0])))
            
            
        #ใส่ความน่าจะเป็น ที่จะถูก Apply G-noise, G-blur
        if self.p >= 0.5:
            if self.gauss_noise:
                image = self.add_gaussian_noise(image)
            if self.gauss_blur:
                image = self.do_gaussian_blur(image)
        # print("===================")
        # print(f"Image shape: {image.shape}")
        if self.transform:
            image = self.transform(image)
            gt_image = self.transform(gt_image)
        return image, gt_image
### END CODE HERE ###

# %%
### START CODE HERE ###
data_dir = "data/img_align_celeba"
image_paths = []
for file_name in os.listdir(data_dir):
    image_paths.append(f"{data_dir}/{file_name}")
print(image_paths)

transform = transforms.Compose([transforms.ToTensor()])

dataset = CustomImageDataset(image_paths=image_paths,
                             gauss_noise=True,
                             gauss_blur=True,
                             resize=128,
                             p=0.5,
                             center_crop=True,
                             transform=transform
                            )
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)



### END CODE HERE ###
# Out:
# ['data/img_align_celeba/000001.jpg', 'data/img_align_celeba/000002.jpg', 'data/img_align_celeba/000003.jpg', 'data/img_align_celeba/000004.jpg', 'data/img_align_celeba/000005.jpg', 'data/img_align_celeba/000006.jpg', 'data/img_align_celeba/000007.jpg', 'data/img_align_celeba/000008.jpg', 'data/img_align_celeba/000009.jpg', 'data/img_align_celeba/000010.jpg', 'data/img_align_celeba/000011.jpg', 'data/img_align_celeba/000012.jpg', 'data/img_align_celeba/000013.jpg', 'data/img_align_celeba/000014.jpg', 'data/img_align_celeba/000015.jpg', 'data/img_align_celeba/000016.jpg', 'data/img_align_celeba/000017.jpg', 'data/img_align_celeba/000018.jpg', 'data/img_align_celeba/000019.jpg', 'data/img_align_celeba/000020.jpg', 'data/img_align_celeba/000021.jpg', 'data/img_align_celeba/000022.jpg', 'data/img_align_celeba/000023.jpg', 'data/img_align_celeba/000024.jpg', 'data/img_align_celeba/000025.jpg', 'data/img_align_celeba/000026.jpg', 'data/img_align_celeba/000027.jpg', 'data/img_align_celeba/000028.jpg', 'data/img_align_celeba/000029.jpg', 'data/img_align_celeba/000030.jpg', 'data/img_align_celeba/000031.jpg', 'data/img_align_celeba/000032.jpg', 'data/img_align_celeba/000033.jpg', 'data/img_align_celeba/000034.jpg', 'data/img_align_celeba/000035.jpg', 'data/img_align_celeba/000036.jpg', 'data/img_align_celeba/000037.jpg', 'data/img_align_celeba/000038.jpg', 'data/img_align_celeba/000039.jpg', 'data/img_align_celeba/000040.jpg', 'data/img_align_celeba/000041.jpg', 'data/img_align_celeba/000042.jpg', 'data/img_align_celeba/000043.jpg', 'data/img_align_celeba/000044.jpg', 'data/img_align_celeba/000045.jpg', 'data/img_align_celeba/000046.jpg', 'data/img_align_celeba/000047.jpg', 'data/img_align_celeba/000048.jpg', 'data/img_align_celeba/000049.jpg', 'data/img_align_celeba/000050.jpg', 'data/img_align_celeba/000051.jpg', 'data/img_align_celeba/000052.jpg', 'data/img_align_celeba/000053.jpg', 'data/img_align_celeba/000054.jpg', 'data/img_align_celeba/000055.jpg', 'data/img_align_celeba/000056.jpg', 'data/img_align_celeba/000057.jpg', 'data/img_align_celeba/000058.jpg', 'data/img_align_celeba/000059.jpg', 'data/img_align_celeba/000060.jpg', 'data/img_align_celeba/000061.jpg', 'data/img_align_celeba/000062.jpg', 'data/img_align_celeba/000063.jpg', 'data/img_align_celeba/000064.jpg', 'data/img_align_celeba/000065.jpg', 'data/img_align_celeba/000066.jpg', 'data/img_align_celeba/000067.jpg', 'data/img_align_celeba/000068.jpg', 'data/img_align_celeba/000069.jpg', 'data/img_align_celeba/000070.jpg', 'data/img_align_celeba/000071.jpg', 'data/img_align_celeba/000072.jpg', 'data/img_align_celeba/000073.jpg', 'data/img_align_celeba/000074.jpg', 'data/img_align_celeba/000075.jpg', 'data/img_align_celeba/000076.jpg', 'data/img_align_celeba/000077.jpg', 'data/img_align_celeba/000078.jpg', 'data/img_align_celeba/000079.jpg', 'data/img_align_celeba/000080.jpg', 'data/img_align_celeba/000081.jpg', 'data/img_align_celeba/000082.jpg', 'data/img_align_celeba/000083.jpg', 'data/img_align_celeba/000084.jpg', 'data/img_align_celeba/000085.jpg', 'data/img_align_celeba/000086.jpg', 'data/img_align_celeba/000087.jpg', 'data/img_align_celeba/000088.jpg', 'data/img_align_celeba/000089.jpg', 'data/img_align_celeba/000090.jpg', 'data/img_align_celeba/000091.jpg', 'data/img_align_celeba/000092.jpg', 'data/img_align_celeba/000093.jpg', 'data/img_align_celeba/000094.jpg', 'data/img_align_celeba/000095.jpg', 'data/img_align_celeba/000096.jpg', 'data/img_align_celeba/000097.jpg', 'data/img_align_celeba/000098.jpg', 'data/img_align_celeba/000099.jpg', 'data/img_align_celeba/000100.jpg', 'data/img_align_celeba/000101.jpg', 'data/img_align_celeba/000102.jpg', 'data/img_align_celeba/000103.jpg', 'data/img_align_celeba/000104.jpg', 'data/img_align_celeba/000105.jpg', 'data/img_align_celeba/000106.jpg', 'data/img_align_celeba/000107.jpg', 'data/img_align_celeba/000108.jpg', 'data/img_align_celeba/000109.jpg', 'data/img_align_celeba/000110.jpg', 'data/img_align_celeba/000111.jpg', 'da ...

# %%
batch,gt_img = next(iter(dataloader)) 
print(batch.shape)
torch.is_tensor(batch)
# Out:
# torch.Size([16, 3, 128, 128])
# True

# %%
### START CODE HERE ###
class DownSamplingBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super(DownSamplingBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.pool(x)
        return x

class UpSamplingBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super(UpSamplingBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.upsample(x)
        return x


class Autoencoder(nn.Module):
    def __init__(self, architecture):
        super(Autoencoder, self).__init__()
        self.architecture = architecture
        #Encoder
        
        if len(self.architecture)  == 3:
            # print("this is 3")
            # print(self.architecture[0])
            self.conv_in = nn.Conv2d(3, self.architecture[0], kernel_size=3, stride=1, padding=1)
            self.down1 = DownSamplingBlock(self.architecture[0], self.architecture[1], kernel_size=3, stride=1, padding=1)
            ### DESIGN YOUR OWN MODEL ###
            self.down2 = DownSamplingBlock(self.architecture[1], self.architecture[2], kernel_size=3, stride=1, padding=1)
            #Decoder
            self.up3 = UpSamplingBlock(self.architecture[2], self.architecture[1], kernel_size=3, stride=1, padding=1)
            self.up4 = UpSamplingBlock(self.architecture[1], self.architecture[0], kernel_size=3, stride=1, padding=1)
            self.conv = nn.Conv2d(self.architecture[0], 3, kernel_size=3, stride=1, padding=1)
        elif len(self.architecture)  == 4:
            # print("this is 4")
            self.conv_in = nn.Conv2d(3, self.architecture[0], kernel_size=3, stride=1, padding=1)
            self.down1 = DownSamplingBlock(self.architecture[0], self.architecture[1], kernel_size=3, stride=1, padding=1)
            ### DESIGN YOUR OWN MODEL ###
            self.down2 = DownSamplingBlock(self.architecture[1], self.architecture[2], kernel_size=3, stride=1, padding=1)
            self.down3 = DownSamplingBlock(self.architecture[2], self.architecture[3], kernel_size=3, stride=1, padding=1)
            #Decoder
            self.up4 = UpSamplingBlock(self.architecture[3], self.architecture[2], kernel_size=3, stride=1, padding=1)
            self.up5 = UpSamplingBlock(self.architecture[2], self.architecture[1], kernel_size=3, stride=1, padding=1)
            self.up6 = UpSamplingBlock(self.architecture[1], self.architecture[0], kernel_size=3, stride=1, padding=1)
            self.conv = nn.Conv2d(self.architecture[0], 3, kernel_size=3, stride=1, padding=1)
    #     self.conv_in = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
    #     self.down1 = DownSamplingBlock(64, 128, kernel_size=3, stride=1, padding=1)
    #     ### DESIGN YOUR OWN MODEL ###
    #     self.down2 = DownSamplingBlock(128, 256, kernel_size=3, stride=1, padding=1)
    #     #Decoder
    #     self.up3 = UpSamplingBlock(256, 128, kernel_size=3, stride=1, padding=1)
    #     self.up4 = UpSamplingBlock(128, 64, kernel_size=3, stride=1, padding=1)
    #     self.conv = nn.Conv2d(64, 3, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        if len(self.architecture)  == 3:
            x = self.conv_in(x)
            x = self.down1(x)
            x = self.down2(x)
            
            x = self.up3(x)
            x = self.up4(x)
            x = self.conv(x)
        if len(self.architecture)  == 4:
            x = self.conv_in(x)
            x = self.down1(x)
            x = self.down2(x)
            x = self.down3(x)
            
            x = self.up4(x)
            x = self.up5(x)
            x = self.up6(x)
            x = self.conv(x)
        return x
### END CODE HERE ###

# %% [markdown]
# **Search Space:**
# - `architecture`:<br>
#     Feature map dimensions for convolutional layers<br>
#     - `[32, 64, 128]`: 3 downsampling layers with feature maps increasing from 32 to 128.
#     - `[64, 128, 256]`: 3 downsampling layers with feature maps starting from 64 to 256.
#     - `[64, 128, 256, 512]`: 4 downsampling layers with more depth, starting from 64 and ending at 512.
# - `learning rates (lr)`:
#     - [1e-3, 8e-4, 1e-4, 1e-2]: Test a wide range of learning rates to evaluate model performance, from 1e-3 (typical) to a more aggressive 1e-2 or conservative 1e-4.
# - `batch size`:
#     - [16, 32]: Explore smaller batch sizes to evaluate their impact on gradient estimation and memory usage.
# - `number of epochs`:
#     - `[10, 50, 100]`: Allow short and long training sessions, from quick evaluations (10 epochs) to more extensive training (100 epochs).
# - `optimizers (opts)`:
#     - `["Adam", "SGD"]`: Compare two popular optimization algorithms: Adam for adaptive learning rates and SGD for momentum-based updates.

# %%
import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.air import session
ray.shutdown()
ray.init(num_gpus=1, ignore_reinit_error=True)

def short_dirname(trial):
    return "trial_" + str(trial.trial_id)

def train_model(config):
    # Extract hyperparameters from config
    architecture = config["architecture"]
    lr = config["lr"]
    batch_size = config["batch_size"]
    num_epochs = config["num_epochs"]
    optimizer = config["optimizer"]
    
    # Split dataset
    train_files, test_files = train_test_split(image_paths, test_size=0.2, random_state=42)
    
    train_dataset = CustomImageDataset(image_paths=train_files, 
                                       gauss_noise=True,
                                       gauss_blur=True,
                                       resize=128,
                                       p=0.5,
                                       center_crop=True,
                                       transform=transform)
    
    test_dataset = CustomImageDataset(image_paths=test_files, 
                                      gauss_noise=True,
                                      gauss_blur=True,
                                      resize=128,
                                      p=0.5,
                                      center_crop=True,
                                      transform=transform)
    
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    testloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = Autoencoder(architecture)
    model = model.to(device)
    loss_fn = nn.MSELoss()
    
    if optimizer == 'Adam':
        opt = torch.optim.Adam(model.parameters(), lr=lr)
    elif optimizer == 'SGD':
        opt = torch.optim.SGD(model.parameters(), lr=lr)
    
    for epoch in range(num_epochs):
        model.train()
        avg_train_loss = 0
        avg_test_loss = 0
        
        for batch in trainloader:
            images, train_gt_img = batch  # unpack the batch
            
            # Move data to the device
            images = images.to(device)
            train_gt_img = train_gt_img.to(device)
            
            # Forward pass
            output = model(images)
            
            # Compute the loss
            loss = loss_fn(output, train_gt_img)
            
            # Backpropagation and optimization step
            opt.zero_grad()
            loss.backward()
            opt.step()

            # Track the training loss
            avg_train_loss += loss.item()
        
        avg_train_loss /= len(trainloader)
        
        total_psnr = 0
        total_ssim = 0
        model.eval()
        
        with torch.no_grad():
            for batch in testloader:
                images, test_gt_img = batch  # Unpack test batch
                
                # Move data to the device
                images = images.to(device)
                test_gt_img = test_gt_img.to(device)
                
                # Forward pass
                output = model(images)
                
                # Compute the loss for test data
                loss = loss_fn(output, test_gt_img)
                avg_test_loss += loss.item()
                
                # Convert tensors to numpy arrays for PSNR and SSIM calculations
                output_np = output.cpu().numpy().transpose(0, 2, 3, 1)
                images_np = test_gt_img.cpu().numpy().transpose(0, 2, 3, 1)
                
                # Calculate PSNR and SSIM for each image in the batch
                for i in range(len(images_np)):  # Use actual batch size
                    img = images_np[i]
                    rec_img = output_np[i]
                    total_psnr += psnr(img, rec_img, data_range=1.0)
                    total_ssim += ssim(img, rec_img, data_range=1.0, multichannel=True)
        
        # Average the PSNR, SSIM, and loss over the test dataset
        avg_psnr = total_psnr / (len(testloader) * len(images_np))
        avg_ssim = total_ssim / (len(testloader) * len(images_np))
        avg_test_loss /= len(testloader)
        
        # Report results to Ray Tune
        session.report({
            "train_loss": avg_train_loss,
            "val_loss": avg_test_loss,
            "val_psnr": avg_psnr,
            "val_ssim": avg_ssim,
        })

config = {
    'architecture': tune.choice([[32, 64, 128], [64, 128, 256], [64, 128, 256, 512]]),
    "lr": tune.grid_search([1e-3, 1e-4, 1e-2]),
    "batch_size": tune.grid_search([16, 32]),
    "num_epochs": tune.grid_search([10, 50, 100]),
    'optimizer': tune.choice(['Adam', 'SGD']),
}

tune.run(
    train_model,
    config=config,
    num_samples=2,  # Number of trials
    trial_dirname_creator=short_dirname,
)
# Out:
# 2024-09-15 21:42:37,271	INFO worker.py:1783 -- Started a local Ray instance.
# 2024-09-15 21:42:39,779	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-09-15 21:43:13</td></tr>
# <tr><td>Running for: </td><td>00:00:33.91        </td></tr>
# <tr><td>Memory:      </td><td>13.6/63.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/16 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 36<br><table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                               </th></tr>
# </thead>
# <tbody>
# <tr><td>train_model_c1dfe_00000</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00000/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00001</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00001/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00002</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00002/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00003</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00003/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00004</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00004/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00005</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00005/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00006</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00006/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00007</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00007/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00008</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00008/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00009</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00009/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00010</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00010/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00011</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00011/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00012</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00012/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00013</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00013/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00014</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00014/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00015</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00015/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00016</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00016/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00017</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00017/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00018</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00018/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00019</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00019/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00020</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00020/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00021</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00021/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00022</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00022/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00023</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_21-42-35_655610_13080/artifacts/2024-09-15_21-42-39/train_model_2024-09-15_21-42-39/driver_artifacts/trial_c1dfe_00023/error.txt</td></tr>
# <tr><td>train_model_c1dfe_00024</td><td style="text-align: right;">           1</td><td>C:/Users/sitth/AppData/Local/Temp/ray/session_2024-09-15_
# 2024-09-15 21:42:52,725	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00004
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=3416, ip=127.0.0.1, actor_id=bd9764f273ce4ba83d0b376801000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# (train_model pid=3416) File data/img_align_celeba/021462.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/016516.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/028075.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/019165.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/012561.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/026003.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/016529.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/002041.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/003316.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/029825.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/009088.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/006138.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/026168.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/001071.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/013589.jpg not found, skipping.
# (train_model pid=3416) File data/img_align_celeba/013204.jpg not found, skipping.
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name             </th></tr>
# </thead>
# <tbody>
# <tr><td>train_model_c1dfe_00000</td></tr>
# <tr><td>train_model_c1dfe_00001</td></tr>
# <tr><td>train_model_c1dfe_00002</td></tr>
# <tr><td>train_model_c1dfe_00003</td></tr>
# <tr><td>train_model_c1dfe_00004</td></tr>
# <tr><td>train_model_c1dfe_00005</td></tr>
# <tr><td>train_model_c1dfe_00006</td></tr>
# <tr><td>train_model_c1dfe_00007</td></tr>
# <tr><td>train_model_c1dfe_00008</td></tr>
# <tr><td>train_model_c1dfe_00009</td></tr>
# <tr><td>train_model_c1dfe_00010</td></tr>
# <tr><td>train_model_c1dfe_00011</td></tr>
# <tr><td>train_model_c1dfe_00012</td></tr>
# <tr><td>train_model_c1dfe_00013</td></tr>
# <tr><td>train_model_c1dfe_00014</td></tr>
# <tr><td>train_model_c1dfe_00015</td></tr>
# <tr><td>train_model_c1dfe_00016</td></tr>
# <tr><td>train_model_c1dfe_00017</td></tr>
# <tr><td>train_model_c1dfe_00018</td></tr>
# <tr><td>train_model_c1dfe_00019</td></tr>
# <tr><td>train_model_c1dfe_00020</td></tr>
# <tr><td>train_model_c1dfe_00021</td></tr>
# <tr><td>train_model_c1dfe_00022</td></tr>
# <tr><td>train_model_c1dfe_00023</td></tr>
# <tr><td>train_model_c1dfe_00024</td></tr>
# <tr><td>train_model_c1dfe_00025</td></tr>
# <tr><td>train_model_c1dfe_00026</td></tr>
# <tr><td>train_model_c1dfe_00027</td></tr>
# <tr><td>train_model_c1dfe_00028</td></tr>
# <tr><td>train_model_c1dfe_00029</td></tr>
# <tr><td>train_model_c1dfe_00030</td></tr>
# <tr><td>train_model_c1dfe_00031</td></tr>
# <tr><td>train_model_c1dfe_00032</td></tr>
# <tr><td>train_model_c1dfe_00033</td></tr>
# <tr><td>train_model_c1dfe_00034</td></tr>
# <tr><td>train_model_c1dfe_00035</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2024-09-15 21:42:52,980	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00009
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=9800, ip=127.0.0.1, actor_id=51e32fd0ef075ea593b293b401000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:53,007	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00003
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=11736, ip=127.0.0.1, actor_id=3f98ebeb867461a722db0e8401000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:53,141	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00006
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=21260, ip=127.0.0.1, actor_id=19a05a109a65f46914f139c601000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:53,671	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00008
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=21096, ip=127.0.0.1, actor_id=88799d96d053742aafb54eb101000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:53,687	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00001
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=9256, ip=127.0.0.1, actor_id=9a7b116437f566d2939694f201000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:53,752	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00005
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=21924, ip=127.0.0.1, actor_id=6f7495a1f94a7f89583df3e801000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:54,053	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00013
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=1616, ip=127.0.0.1, actor_id=8d61c4c13cb56d5a12a9c66e01000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:42:54,063	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00012
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
# ...
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=3368, ip=127.0.0.1, actor_id=b066093e62ea8f484a8d2b3d01000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:43:13,636	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00033
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=20576, ip=127.0.0.1, actor_id=4872556d90dc931166b25ffd01000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:43:13,668	ERROR tune_controller.py:1331 -- Trial task failed for trial train_model_c1dfe_00035
# Traceback (most recent call last):
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 2661, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=25404, ip=127.0.0.1, actor_id=b3473c081796e9afc2d6025c01000000, repr=train_model)
#   File "python\ray\_raylet.pyx", line 1858, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1799, in ray._raylet.execute_task.function_executor
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\air\_internal\util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\sitth\AppData\Local\Temp\ipykernel_13080\2746204585.py", line 56, in train_model
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 630, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py", line 673, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 317, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\collate.py", line 192, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
# 2024-09-15 21:43:13,715	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'C:/Users/sitth/ray_results/train_model_2024-09-15_21-42-39' in 0.0406s.
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[24], line 130
#     115         session.report({
#     116             "train_loss": avg_train_loss,
#     117             "val_loss": avg_test_loss,
#     118             "val_psnr": avg_psnr,
#     119             "val_ssim": avg_ssim,
#     120         })
#     122 config = {
#     123     'architecture': tune.choice([[32, 64, 128], [64, 128, 256], [64, 128, 256, 512]]),
#     124     "lr": tune.grid_search([1e-3, 1e-4, 1e-2]),
#    (...)
#     127     'optimizer': tune.choice(['Adam', 'SGD']),
#     128 }
# --> 130 tune.run(
#     131     train_model,
#     132     config=config,
#     133     num_samples=2,  # Number of trials
#     134     trial_dirname_creator=short_dirname,
#     135 )
#
# File c:\Users\sitth\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\tune.py:1035, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033 if incomplete_trials:
#    1034     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035         raise TuneError("Trials did not complete", incomplete_trials)
#    1036     else:
#    1037         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [train_model_c1dfe_00000, train_model_c1dfe_00001, train_model_c1dfe_00002, train_model_c1dfe_00003, train_model_c1dfe_00004, train_model_c1dfe_00005, train_model_c1dfe_00006, train_model_c1dfe_00007, train_model_c1dfe_00008, train_model_c1dfe_00009, train_model_c1dfe_00010, train_model_c1dfe_00011, train_model_c1dfe_00012, train_model_c1dfe_00013, train_model_c1dfe_00014, train_model_c1dfe_00015, train_model_c1dfe_00016, train_model_c1dfe_00017, train_model_c1dfe_00018, train_model_c1dfe_00019, train_model_c1dfe_00020, train_model_c1dfe_00021, train_model_c1dfe_00022, train_model_c1dfe_00023, train_model_c1dfe_00024, train_model_c1dfe_00025, train_model_c1dfe_00026, train_model_c1dfe_00027, train_model_c1dfe_00028, train_model_c1dfe_00029, train_model_c1dfe_00030, train_model_c1dfe_00031, train_model_c1dfe_00032, train_model_c1dfe_00033, train_model_c1dfe_00034, train_model_c1dfe_00035])
